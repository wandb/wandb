# %%
# !pip install -e ../

# %%
import wandb
import time

# %%
# Single cell logging
wandb.init(project="jupyter_test")
for i in range(10):
    time.sleep(0.5)
    wandb.log({"metric": i})

# %%
for i in range(10):
    time.sleep(0.5)
    wandb.log({"metric": i})

# %%
wandb.join()
